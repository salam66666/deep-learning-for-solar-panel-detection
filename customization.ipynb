# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# 配置参数
ORIGINAL_HEIGHT = 24
ORIGINAL_WIDTH = 40
TARGET_HEIGHT = 128
TARGET_WIDTH = int(ORIGINAL_WIDTH * (TARGET_HEIGHT/ORIGINAL_HEIGHT))  # 213
BATCH_SIZE = 32
NUM_CLASSES = 8
EPOCHS = 50
SEED = 42

DATASET_DIR = r'E:\CDUT\English\7 Term\Project\model\archive\8classes'

# 修复后的Inception模块
class InceptionModule(layers.Layer):
    def __init__(self, filters, name="inception_block", **kwargs):
        super().__init__(name=name, **kwargs)
        self.filters = filters
        
        # 分支1: 1x1卷积
        self.branch1 = models.Sequential([
            layers.Conv2D(filters[0], (1,1), padding='same', activation='relu'),
        ])
        # 分支2: 1x1 + 3x3卷积
        self.branch2 = models.Sequential([
            layers.Conv2D(filters[1], (1,1), padding='same', activation='relu'),
            layers.Conv2D(filters[2], (3,3), padding='same', activation='relu')
        ])
        # 分支3: 1x1 + 5x5卷积
        self.branch3 = models.Sequential([
            layers.Conv2D(filters[3], (1,1), padding='same', activation='relu'),
            layers.Conv2D(filters[4], (5,5), padding='same', activation='relu')
        ])
        # 分支4: 3x3池化 + 1x1卷积
        self.branch4 = models.Sequential([
            layers.MaxPooling2D((3,3), strides=(1,1), padding='same'),
            layers.Conv2D(filters[5], (1,1), padding='same', activation='relu')
        ])
        
    def call(self, inputs):
        return layers.concatenate([
            self.branch1(inputs),
            self.branch2(inputs),
            self.branch3(inputs),
            self.branch4(inputs)
        ], axis=-1)
    
    # 新增get_config方法
    def get_config(self):
        config = super().get_config()
        config.update({
            'filters': self.filters
        })
        return config

# 多头注意力机制（保持原实现）
class MultiHeadAttention(layers.Layer):
    def __init__(self, num_heads, key_dim, name="multihead_attn", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_heads = num_heads
        self.key_dim = key_dim
        self.Wq = layers.Dense(key_dim * num_heads)
        self.Wk = layers.Dense(key_dim * num_heads)
        self.Wv = layers.Dense(key_dim * num_heads)
        self.dense = layers.Dense(key_dim * num_heads)

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        
        # 生成Q,K,V
        Q = self.Wq(inputs)
        K = self.Wk(inputs)
        V = self.Wv(inputs)
        
        # 分割多头
        Q = tf.reshape(Q, [batch_size, -1, self.num_heads, self.key_dim])
        K = tf.reshape(K, [batch_size, -1, self.num_heads, self.key_dim])
        V = tf.reshape(V, [batch_size, -1, self.num_heads, self.key_dim])
        
        # 计算注意力分数
        attention = tf.einsum('bqhd,bkhd->bhqk', Q, K) / tf.sqrt(tf.cast(self.key_dim, tf.float32))
        attention = tf.nn.softmax(attention, axis=-1)
        
        # 应用注意力权重
        output = tf.einsum('bhqk,bkhd->bqhd', attention, V)
        output = tf.reshape(output, [batch_size, -1, self.num_heads * self.key_dim])
        
        return self.dense(output), attention
    
    def get_config(self):
        config = super().get_config()
        config.update({
            'num_heads': self.num_heads,
            'key_dim': self.key_dim
        })
        return config


# 构建混合模型
def build_hybrid_model():
    inputs = layers.Input(shape=(TARGET_HEIGHT, TARGET_WIDTH, 3))
    
    # 初始卷积
    x = layers.Conv2D(32, (3,3), padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    
    # Inception模块（使用修复后的实现）
    x = InceptionModule([16, 16, 32, 16, 32, 16], name="inception_block")(x)
    x = layers.MaxPooling2D((2,2), name="pooling_after_inception")(x)  # 64x106
    
    # 转换为序列数据
    x = layers.Reshape((64, 106 * 96), name="reshape_to_sequence")(x)
    
    # BiLSTM层
    x = layers.Bidirectional(
        layers.LSTM(128, return_sequences=True, 
                    activation='tanh',
                    recurrent_activation='sigmoid'),
        name="bilstm_layer"
    )(x)

    x = layers.Dropout(0.3)(x)
    
    # 多头注意力
    attn_output, attn_weights = MultiHeadAttention(
        num_heads=4, 
        key_dim=32,
        name="multihead_attention"
    )(x)
    x = layers.Concatenate(name="attention_concat")([x, attn_output])
    
    # 分类头
    x = layers.GlobalAveragePooling1D(name="global_pool")(x)
    x = layers.Dense(256, activation='relu', name="dense_1")(x)
    x = layers.Dropout(0.5, name="final_dropout")(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax', name="output")(x)
    
    return models.Model(inputs, outputs)

# 数据准备函数
def prepare_datasets(root_dir):
    image_paths = []
    labels = []
    class_names = sorted(os.listdir(root_dir))
    
    for label_idx, class_name in enumerate(class_names):
        class_dir = os.path.join(root_dir, class_name)
        for filename in os.listdir(class_dir):
            if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_paths.append(os.path.join(class_dir, filename))
                labels.append(label_idx)
    
    return image_paths, np.array(labels), class_names

# 图像预处理
def preprocess_image(image, augment=False):
    image = tf.image.resize(
        image, [TARGET_HEIGHT, TARGET_WIDTH],
        method=tf.image.ResizeMethod.BICUBIC
    )
    image = tf.cast(image, tf.float32)
    
    if augment:
        image = tf.image.random_brightness(image, max_delta=0.1)
        image = tf.image.random_contrast(image, lower=0.9, upper=1.1)

    return image/255.0

# 创建数据集
def create_dataset(image_paths, labels, augment=False):
    def parse_function(path, label):
        image = tf.io.decode_jpeg(tf.io.read_file(path), channels=3)
        return preprocess_image(image, augment), label
    
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(parse_function, num_parallel_calls=tf.data.AUTOTUNE)
    return dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# 可视化组件
def visualize_components(model, test_dataset):
    # 创建中间模型（使用正确的层名称）
    intermediate_model = models.Model(
        inputs=model.input,
        outputs=[
            model.get_layer("inception_block").output,
            model.get_layer("bilstm_layer").output,
            model.get_layer("multihead_attention").output[1]  # 获取注意力权重
        ]
    )
    
    # 获取样本数据
    sample_images, _ = next(iter(test_dataset.take(1)))
    features = intermediate_model.predict(sample_images)
    
    # 可视化设置
    plt.figure(figsize=(18, 6))
    
    # Inception特征图
    plt.subplot(1,3,1)
    plt.imshow(features[0][0,...,:3])  # 显示前3个通道
    plt.title('Inception Block Features')
    
    # BiLSTM激活模式
    plt.subplot(1,3,2)
    lstm_act = np.mean(features[1][0], axis=0)
    plt.plot(lstm_act)
    plt.title('BiLSTM Activation Profile')
    
    # 注意力热力图
    plt.subplot(1,3,3)
    plt.imshow(features[2][0][0], cmap='viridis')  # 第一个注意力头
    plt.colorbar()
    plt.title('Multi-Head Attention Heatmap')
    
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    # 准备数据
    image_paths, labels, class_names = prepare_datasets(DATASET_DIR)
    X_train, X_test, y_train, y_test = train_test_split(
        image_paths, labels, test_size=0.2, stratify=labels, random_state=SEED)
    
    # 创建数据集
    train_dataset = create_dataset(X_train, y_train, augment=True)
    test_dataset = create_dataset(X_test, y_test, augment=True)
    
    # 构建模型
    model = build_hybrid_model()
    optimizer = optimizers.Adam(learning_rate=1e-4)
    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    model.summary()
    
    # 类别权重
    class_weights = class_weight.compute_class_weight(
        'balanced', classes=np.unique(y_train), y=y_train)
    class_weights = dict(enumerate(class_weights))
    
    # 训练配置
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=15,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ModelCheckpoint(
            'best_model.h5',
            save_best_only=True,
            monitor='val_accuracy'
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=1e-6
        )
    ]
    
    # 训练模型
    history = model.fit(
        train_dataset,
        validation_data=test_dataset,
        epochs=EPOCHS,
        class_weight=class_weights,
        callbacks=callbacks
    )
    
    # 保存最终模型
    model.save('final_model.h5', save_format='h5')
    
    # 可视化组件
    visualize_components(model, test_dataset)
    
    # 训练过程可视化
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title('Training Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Training Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # 生成分类报告
    y_pred = np.argmax(model.predict(test_dataset), axis=1)
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 213, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 213, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 213, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# inception_block (InceptionModul (None, 128, 213, 96) 19584       batch_normalization[0][0]
# __________________________________________________________________________________________________
# pooling_after_inception (MaxPoo (None, 64, 106, 96)  0           inception_block[0][0]
# __________________________________________________________________________________________________
# reshape_to_sequence (Reshape)   (None, 64, 10176)    0           pooling_after_inception[0][0]
# __________________________________________________________________________________________________
# bilstm_layer (Bidirectional)    (None, 64, 256)      10552320    reshape_to_sequence[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64, 256)      0           bilstm_layer[0][0]
# __________________________________________________________________________________________________
# multihead_attention (MultiHeadA ((None, None, 128),  115200      dropout[0][0]
# __________________________________________________________________________________________________
# attention_concat (Concatenate)  (None, 64, 384)      0           dropout[0][0]
#                                                                  multihead_attention[0][0]
# __________________________________________________________________________________________________
# global_pool (GlobalAveragePooli (None, 384)          0           attention_concat[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          98560       global_pool[0][0]
# __________________________________________________________________________________________________
# final_dropout (Dropout)         (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 8)            2056        final_dropout[0][0]
# ==================================================================================================
# Total params: 10,788,744
# Trainable params: 10,788,680
# Non-trainable params: 64
# __________________________________________________________________________________________________
# Epoch 1/50
# 166/166 [==============================] - 21s 98ms/step - loss: 1.9180 - accuracy: 0.2689 - val_loss: 1.9330 - val_accuracy: 0.2387
# Epoch 2/50
# 166/166 [==============================] - 16s 94ms/step - loss: 1.6617 - accuracy: 0.3887 - val_loss: 1.7055 - val_accuracy: 0.3459
# Epoch 3/50
# 166/166 [==============================] - 16s 96ms/step - loss: 1.5353 - accuracy: 0.4352 - val_loss: 1.5155 - val_accuracy: 0.4441
# Epoch 4/50
# 166/166 [==============================] - 16s 98ms/step - loss: 1.4324 - accuracy: 0.4760 - val_loss: 1.4206 - val_accuracy: 0.4721
# Epoch 5/50
# 166/166 [==============================] - 17s 101ms/step - loss: 1.3711 - accuracy: 0.4991 - val_loss: 1.3555 - val_accuracy: 0.4992
# Epoch 6/50
# 166/166 [==============================] - 17s 101ms/step - loss: 1.3040 - accuracy: 0.5185 - val_loss: 1.3119 - val_accuracy: 0.5128
# Epoch 7/50
# 166/166 [==============================] - 17s 102ms/step - loss: 1.2578 - accuracy: 0.5438 - val_loss: 1.3077 - val_accuracy: 0.5076
# Epoch 8/50
# 166/166 [==============================] - 17s 102ms/step - loss: 1.2080 - accuracy: 0.5646 - val_loss: 1.2701 - val_accuracy: 0.5257
# Epoch 9/50
# 166/166 [==============================] - 17s 102ms/step - loss: 1.1694 - accuracy: 0.5714 - val_loss: 1.2562 - val_accuracy: 0.5159
# Epoch 10/50
# 166/166 [==============================] - 17s 102ms/step - loss: 1.1135 - accuracy: 0.5981 - val_loss: 1.2392 - val_accuracy: 0.5453
# Epoch 11/50
# 166/166 [==============================] - 17s 103ms/step - loss: 1.0827 - accuracy: 0.6030 - val_loss: 1.2262 - val_accuracy: 0.5431
# Epoch 12/50
# 166/166 [==============================] - 17s 103ms/step - loss: 1.0409 - accuracy: 0.6187 - val_loss: 1.2174 - val_accuracy: 0.5453
# Epoch 13/50
# 166/166 [==============================] - 17s 103ms/step - loss: 1.0042 - accuracy: 0.6306 - val_loss: 1.2170 - val_accuracy: 0.5551
# Epoch 14/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.9789 - accuracy: 0.6415 - val_loss: 1.2189 - val_accuracy: 0.5491
# Epoch 15/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.9387 - accuracy: 0.6529 - val_loss: 1.2333 - val_accuracy: 0.5483
# Epoch 16/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.9147 - accuracy: 0.6655 - val_loss: 1.2312 - val_accuracy: 0.5566
# Epoch 17/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.8814 - accuracy: 0.6725 - val_loss: 1.2055 - val_accuracy: 0.5566
# Epoch 18/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.8478 - accuracy: 0.6859 - val_loss: 1.2037 - val_accuracy: 0.5770
# Epoch 19/50
# 166/166 [==============================] - 17s 102ms/step - loss: 0.7997 - accuracy: 0.7126 - val_loss: 1.2174 - val_accuracy: 0.5937
# Epoch 20/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.7774 - accuracy: 0.7132 - val_loss: 1.2498 - val_accuracy: 0.5680
# Epoch 21/50
# 166/166 [==============================] - 17s 104ms/step - loss: 0.7510 - accuracy: 0.7285 - val_loss: 1.2434 - val_accuracy: 0.5718
# Epoch 22/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.7208 - accuracy: 0.7356 - val_loss: 1.2700 - val_accuracy: 0.5710
# Epoch 23/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.6779 - accuracy: 0.7517 - val_loss: 1.2904 - val_accuracy: 0.5650
# Epoch 24/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.5968 - accuracy: 0.7889 - val_loss: 1.2620 - val_accuracy: 0.5974
# Epoch 25/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.5488 - accuracy: 0.8076 - val_loss: 1.2913 - val_accuracy: 0.5846
# Epoch 26/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.5225 - accuracy: 0.8112 - val_loss: 1.3093 - val_accuracy: 0.5853
# Epoch 27/50
# 166/166 [==============================] - 17s 104ms/step - loss: 0.4905 - accuracy: 0.8313 - val_loss: 1.3346 - val_accuracy: 0.5921
# Epoch 28/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.4759 - accuracy: 0.8301 - val_loss: 1.3462 - val_accuracy: 0.5823
# Epoch 29/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.4191 - accuracy: 0.8553 - val_loss: 1.3268 - val_accuracy: 0.6073
# Epoch 30/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.3870 - accuracy: 0.8675 - val_loss: 1.3561 - val_accuracy: 0.6027
# Epoch 31/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.3723 - accuracy: 0.8664 - val_loss: 1.3696 - val_accuracy: 0.6035
# Epoch 32/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.3519 - accuracy: 0.8859 - val_loss: 1.3901 - val_accuracy: 0.5952
# Epoch 33/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.3463 - accuracy: 0.8830 - val_loss: 1.3864 - val_accuracy: 0.6005
# Epoch 34/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.3238 - accuracy: 0.8915 - val_loss: 1.3816 - val_accuracy: 0.5974
# Epoch 35/50
# 166/166 [==============================] - 17s 104ms/step - loss: 0.3061 - accuracy: 0.9044 - val_loss: 1.3884 - val_accuracy: 0.6042
# Epoch 36/50
# 166/166 [==============================] - 17s 104ms/step - loss: 0.2918 - accuracy: 0.9065 - val_loss: 1.4325 - val_accuracy: 0.6012
# Epoch 37/50
# 166/166 [==============================] - 17s 104ms/step - loss: 0.2900 - accuracy: 0.9065 - val_loss: 1.4265 - val_accuracy: 0.5982
# Epoch 38/50
# 166/166 [==============================] - 17s 105ms/step - loss: 0.2869 - accuracy: 0.9074 - val_loss: 1.4368 - val_accuracy: 0.5982
# Epoch 39/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.2740 - accuracy: 0.9121 - val_loss: 1.4333 - val_accuracy: 0.6027
# Epoch 40/50
# 166/166 [==============================] - 17s 103ms/step - loss: 0.2590 - accuracy: 0.9150 - val_loss: 1.4430 - val_accuracy: 0.5997
# Epoch 41/50
# 166/166 [==============================] - 17s 102ms/step - loss: 0.2666 - accuracy: 0.9153 - val_loss: 1.4370 - val_accuracy: 0.6050
# Epoch 42/50
# 166/166 [==============================] - 17s 102ms/step - loss: 0.2591 - accuracy: 0.9161 - val_loss: 1.4514 - val_accuracy: 0.6027
# Epoch 43/50
# 166/166 [==============================] - 17s 102ms/step - loss: 0.2528 - accuracy: 0.9225 - val_loss: 1.4472 - val_accuracy: 0.6073
# Epoch 44/50
# 166/166 [==============================] - 17s 102ms/step - loss: 0.2423 - accuracy: 0.9233 - val_loss: 1.4498 - val_accuracy: 0.6012
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Classification Report:
#                 precision    recall  f1-score   support
#
#           Cell       0.46      0.40      0.43       165
#     Cell-Multi       0.42      0.42      0.42       165
#       Cracking       0.70      0.58      0.64       166
#          Diode       0.81      0.82      0.81       166
#     No-Anomaly       0.57      0.66      0.61       166
# Offline-Module       0.65      0.71      0.68       165
#      Shadowing       0.61      0.66      0.64       166
#     Vegetation       0.58      0.55      0.57       165
#
#       accuracy                           0.60      1324
#      macro avg       0.60      0.60      0.60      1324
#   weighted avg       0.60      0.60      0.60      1324

# %%
import matplotlib.pyplot as plt

# 添加预处理可视化检查
test_image = next(iter(train_dataset.take(1)))[0][0]
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("Original (24x40)")
plt.imshow(tf.image.resize(test_image, (24,40)))
plt.subplot(1,2,2)
plt.title("Scaled (128x213)")
plt.imshow(test_image)
plt.show()

# %%
# ...（保持之前的导入和配置参数不变）

def plot_class_distribution(y_train, y_test, class_names):
    """可视化训练集与验证集的类别分布"""
    # 统计各类别数量
    train_counts = np.bincount(y_train, minlength=NUM_CLASSES)
    test_counts = np.bincount(y_test, minlength=NUM_CLASSES)
    
    # 创建画布
    plt.figure(figsize=(14, 8))
    
    # 设置柱状图参数
    bar_width = 0.35
    index = np.arange(NUM_CLASSES)
    
    # 颜色方案
    train_color = '#1f77b4'  # 蓝色
    test_color = '#ff7f0e'   # 橙色
    
    # 绘制柱状图
    bars_train = plt.bar(index - bar_width/2, train_counts, bar_width,
                        color=train_color, label='Train')
    bars_test = plt.bar(index + bar_width/2, test_counts, bar_width,
                       color=test_color, label='Validation')
    
    # 添加数值标签
    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2., height,
                     f'{height}',
                     ha='center', va='bottom', fontsize=10)
    
    add_labels(bars_train)
    add_labels(bars_test)
    
    # 图表装饰
    plt.title(f'Class Distribution ({NUM_CLASSES} classes)', fontsize=14, pad=20)
    plt.xlabel('Defect Type', fontsize=12)
    plt.ylabel('Number of Samples', fontsize=12)
    plt.xticks(index, class_names, rotation=45, ha='right', fontsize=10)
    plt.legend()
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()

# 主流程
if __name__ == "__main__":
    # 准备数据
    image_paths, labels, class_names = prepare_datasets(DATASET_DIR)
    
    # 数据分割
    X_train, X_test, y_train, y_test = train_test_split(
        image_paths, labels, test_size=0.2, stratify=labels, random_state=SEED)
    
    # ==================== 新增可视化调用 ==================== 
    plot_class_distribution(
        y_train=y_train,
        y_test=y_test,
        class_names=class_names  # 直接使用原始类别名称
    )
    # ========================================================
    
    # 创建数据集（后续代码保持不变）
    train_dataset = create_dataset(X_train, y_train, augment=True)
    test_dataset = create_dataset(X_test, y_test)
    
    # ...（后续模型构建、训练等代码保持不变）

# %%
# Additional necessary imports
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    f1_score,
    accuracy_score,
    precision_score,
    recall_score,
    precision_recall_curve,
    average_precision_score
)
from sklearn.preprocessing import label_binarize
import seaborn as sns

# ... (keep previous code unchanged until training completes)

if __name__ == "__main__":
    # ... (previous data preparation and training code remains unchanged)
    
    # ==================== Evaluation Code Block ====================
    # Get test set predictions
    y_pred_probs = model.predict(test_dataset)
    y_pred = np.argmax(y_pred_probs, axis=1)
    
    # Extract true labels
    y_true = np.concatenate([y.numpy() for _, y in test_dataset], axis=0)
    
    # Display prediction samples
    print("\nSample predictions comparison:")
    print("Predicted labels:", y_pred[:10])
    print("True labels:", y_true[:10])
    
    # Confusion matrix visualization
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=class_names, 
                yticklabels=class_names)
    plt.xlabel("Predicted Label", fontsize=12)
    plt.ylabel("True Label", fontsize=12)
    plt.title("Confusion Matrix", fontsize=14)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()
    
    # Multiclass ROC Curve (OvR strategy)
    n_classes = len(class_names)
    y_true_bin = label_binarize(y_true, classes=range(n_classes))
    
    # Calculate metrics for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    
    # Compute macro-average
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
    mean_tpr /= n_classes
    
    plt.figure(figsize=(8, 6))
    plt.plot(all_fpr, mean_tpr, color='darkorange',
             label=f'Macro-average ROC Curve (AUC = {auc(all_fpr, mean_tpr):.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title('Multiclass ROC Curve', fontsize=14)
    plt.legend(loc="lower right")
    plt.tight_layout()
    plt.show()

    # ==================== PR Curve Block ====================
    precision = dict()
    recall = dict()
    average_precision = dict()
    
    plt.figure(figsize=(8, 6))
    colors = sns.color_palette("husl", n_classes)
    
    # Plot PR curves for each class
    for i in range(n_classes):
        precision[i], recall[i], _ = precision_recall_curve(y_true_bin[:, i], y_pred_probs[:, i])
        average_precision[i] = average_precision_score(y_true_bin[:, i], y_pred_probs[:, i])
        plt.plot(recall[i], precision[i], color=colors[i], alpha=0.3,
                 label=f'{class_names[i]} (AP={average_precision[i]:.2f})')
    
    # Compute macro-average PR curve
    precision["macro"], recall["macro"], _ = precision_recall_curve(
        y_true_bin.ravel(), y_pred_probs.ravel()
    )
    average_precision["macro"] = average_precision_score(y_true_bin, y_pred_probs, average="macro")
    
    plt.plot(recall["macro"], precision["macro"], color='darkorange', lw=2,
             label=f'Macro-average (AP={average_precision["macro"]:.2f})')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Recall', fontsize=12)
    plt.ylabel('Precision', fontsize=12)
    plt.title('Multiclass Precision-Recall Curve', fontsize=14)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # Key metrics output
    print("\nKey Metrics:")
    print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
    print(f"Macro-average Precision: {precision_score(y_true, y_pred, average='macro'):.4f}")
    print(f"Macro-average Recall: {recall_score(y_true, y_pred, average='macro'):.4f}")
    print(f"Macro-average F1: {f1_score(y_true, y_pred, average='macro'):.4f}")
    print(f"Macro-average AP: {average_precision['macro']:.4f}")
    
    # Detailed classification report
    print("\nDetailed Classification Report:")
    print(classification_report(y_true, y_pred, 
                                target_names=class_names,
                                digits=4))
    # ========================================================
# Out:
# Sample predictions comparison:
# Predicted labels: [4 5 1 4 4 7 6 7 4 4]
# True labels: [5 5 0 4 4 7 6 7 1 4]
# Key Metrics:
# Accuracy: 0.6065
# Macro-average Precision: 0.6048
# Macro-average Recall: 0.6062
# Macro-average F1: 0.6039
# Macro-average AP: 0.6443
#
# Detailed Classification Report:
#                 precision    recall  f1-score   support
#
#           Cell     0.4558    0.4061    0.4295       165
#     Cell-Multi     0.4172    0.4121    0.4146       165
#       Cracking     0.6950    0.5904    0.6384       166
#          Diode     0.8225    0.8373    0.8299       166
#     No-Anomaly     0.5737    0.6566    0.6124       166
# Offline-Module     0.6467    0.7212    0.6819       165
#      Shadowing     0.6313    0.6807    0.6551       166
#     Vegetation     0.5960    0.5455    0.5696       165
#
#       accuracy                         0.6065      1324
#      macro avg     0.6048    0.6062    0.6039      1324
#   weighted avg     0.6050    0.6065    0.6042      1324

# %%
from tensorflow.keras.applications import ResNet50, DenseNet121, MobileNetV2
from tensorflow.keras import layers, models, optimizers
import matplotlib.pyplot as plt

# ====================================
# 统一构建预训练模型
# ====================================
def build_pretrained_model(base_model_class, name):
    base_model = base_model_class(
        include_top=False,
        weights='imagenet',
        input_shape=(TARGET_HEIGHT, TARGET_WIDTH, 3),
        pooling='avg'
    )
    base_model.trainable = False

    inputs = layers.Input(shape=(TARGET_HEIGHT, TARGET_WIDTH, 3))
    x = base_model(inputs, training=False)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

    model = models.Model(inputs, outputs, name=name)
    return model

# ====================================
# 用统一配置训练模型
# ====================================
def train_model(model, name):
    model.compile(
        optimizer=optimizers.Adam(learning_rate=1e-4),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    history = model.fit(
        train_dataset,
        validation_data=test_dataset,
        epochs=EPOCHS,
        class_weight=class_weights,
        callbacks=callbacks,
        verbose=1
    )

    _, test_acc = model.evaluate(test_dataset, verbose=0)
    print(f"{name} 测试准确率: {test_acc:.4f}")
    return test_acc, history

# ====================================
# 记录和对比四个模型的结果
# ====================================
# 原模型准确率
_, my_model_acc = model.evaluate(test_dataset, verbose=0)

# 记录所有模型
results = {"MyModel": my_model_acc}
histories = {"MyModel": history}

# 模型字典
model_classes = {
    "ResNet50": ResNet50,
    "DenseNet121": DenseNet121,
    "MobileNetV2": MobileNetV2
}

# 训练三个预训练模型
for name, cls in model_classes.items():
    pretrained_model = build_pretrained_model(cls, name)
    acc, h = train_model(pretrained_model, name)
    results[name] = acc
    histories[name] = h

# ====================================
# 准确率柱状图
# ====================================
plt.figure(figsize=(8, 5))
plt.bar(results.keys(), results.values())
plt.ylabel("Accuracy")
plt.title("Comparison of model test accuracy")
plt.ylim(0, 1)
for i, (k, v) in enumerate(results.items()):
    plt.text(i, v + 0.01, f"{v:.2f}", ha='center')
plt.show()

# ====================================
# 训练过程对比图（Accuracy）
# ====================================
plt.figure(figsize=(12, 5))
for name, h in histories.items():
    plt.plot(h.history['val_accuracy'], label=f'{name}')
plt.title('Validation Accuracy Comparison')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# 166/166 [==============================] - 11s 53ms/step - loss: 2.2113 - accuracy: 0.1196 - val_loss: 2.0831 - val_accuracy: 0.1276
# Epoch 2/50
# 166/166 [==============================] - 8s 49ms/step - loss: 2.1159 - accuracy: 0.1181 - val_loss: 2.0817 - val_accuracy: 0.1450
# Epoch 3/50
# 166/166 [==============================] - 8s 49ms/step - loss: 2.0960 - accuracy: 0.1185 - val_loss: 2.0797 - val_accuracy: 0.1337
# Epoch 4/50
# 166/166 [==============================] - 8s 51ms/step - loss: 2.0846 - accuracy: 0.1332 - val_loss: 2.0790 - val_accuracy: 0.1435
# Epoch 5/50
# 166/166 [==============================] - 8s 51ms/step - loss: 2.0816 - accuracy: 0.1245 - val_loss: 2.0781 - val_accuracy: 0.1292
# Epoch 6/50
# 166/166 [==============================] - 8s 50ms/step - loss: 2.0800 - accuracy: 0.1311 - val_loss: 2.0777 - val_accuracy: 0.1254
# Epoch 7/50
# 166/166 [==============================] - 9s 55ms/step - loss: 2.0788 - accuracy: 0.1340 - val_loss: 2.0782 - val_accuracy: 0.1299
# Epoch 8/50
# 166/166 [==============================] - 12s 71ms/step - loss: 2.0788 - accuracy: 0.1355 - val_loss: 2.0776 - val_accuracy: 0.1292
# Epoch 9/50
# 166/166 [==============================] - 12s 71ms/step - loss: 2.0782 - accuracy: 0.1387 - val_loss: 2.0777 - val_accuracy: 0.1269
# Epoch 10/50
# 166/166 [==============================] - 12s 70ms/step - loss: 2.0787 - accuracy: 0.1413 - val_loss: 2.0774 - val_accuracy: 0.1269
# Epoch 11/50
# 166/166 [==============================] - 12s 70ms/step - loss: 2.0777 - accuracy: 0.1393 - val_loss: 2.0776 - val_accuracy: 0.1254
# Epoch 12/50
# 166/166 [==============================] - 9s 55ms/step - loss: 2.0777 - accuracy: 0.1440 - val_loss: 2.0769 - val_accuracy: 0.1337
# Epoch 13/50
# 166/166 [==============================] - 8s 51ms/step - loss: 2.0780 - accuracy: 0.1347 - val_loss: 2.0767 - val_accuracy: 0.1541
# Epoch 14/50
# 166/166 [==============================] - 9s 51ms/step - loss: 2.0770 - accuracy: 0.1446 - val_loss: 2.0770 - val_accuracy: 0.1254
# Epoch 15/50
# 166/166 [==============================] - 8s 50ms/step - loss: 2.0770 - accuracy: 0.1417 - val_loss: 2.0770 - val_accuracy: 0.1254
# Epoch 16/50
# 166/166 [==============================] - 8s 51ms/step - loss: 2.0768 - accuracy: 0.1476 - val_loss: 2.0773 - val_accuracy: 0.1412
# Epoch 17/50
# 166/166 [==============================] - 9s 52ms/step - loss: 2.0776 - accuracy: 0.1374 - val_loss: 2.0761 - val_accuracy: 0.1881
# Epoch 18/50
# 166/166 [==============================] - 8s 51ms/step - loss: 2.0758 - accuracy: 0.1444 - val_loss: 2.0758 - val_accuracy: 0.1503
# Epoch 19/50
# 166/166 [==============================] - 8s 50ms/step - loss: 2.0758 - accuracy: 0.1425 - val_loss: 2.0756 - val_accuracy: 0.1465
# Epoch 20/50
# 166/166 [==============================] - 8s 51ms/step - loss: 2.0762 - accuracy: 0.1444 - val_loss: 2.0752 - val_accuracy: 0.1571
# Epoch 21/50
# 166/166 [==============================] - 12s 70ms/step - loss: 2.0755 - accuracy: 0.1408 - val_loss: 2.0757 - val_accuracy: 0.1443
# Epoch 22/50
# 166/166 [==============================] - 12s 71ms/step - loss: 2.0753 - accuracy: 0.1451 - val_loss: 2.0750 - val_accuracy: 0.1495
# Epoch 23/50
# 166/166 [==============================] - 12s 71ms/step - loss: 2.0750 - accuracy: 0.1447 - val_loss: 2.0750 - val_accuracy: 0.1594
# Epoch 24/50
# 166/166 [==============================] - 12s 71ms/step - loss: 2.0743 - accuracy: 0.1498 - val_loss: 2.0742 - val_accuracy: 0.1798
# Epoch 25/50
# 166/166 [==============================] - 9s 57ms/step - loss: 2.0742 - accuracy: 0.1591 - val_loss: 2.0740 - val_accuracy: 0.1669
# Epoch 26/50
# 166/166 [==============================] - 8s 50ms/step - loss: 2.0740 - accuracy: 0.1500 - val_loss: 2.0738 - val_accuracy: 0.1518
# Epoch 27/50
# 166/166 [==============================] - 8s 51ms/step - loss: 2.0732 - accuracy: 0.1519 - val_loss: 2.0734 - val_accuracy: 0.1375
# Epoch 28/50
# 166/166 [==============================] - 8s 49ms/step - loss: 2.0735 - accuracy: 0.1472 - val_loss: 2.0731 - val_accuracy: 0.1337
# Epoch 29/50
# 166/166 [==============================] - 8s 49ms/step - loss: 2.0734 - accuracy: 0.1495 - val_loss: 2.0731 - val_accuracy: 0.1654
# Epoch 30/50
# 166/166 [==============================] - 8s 50ms/step - loss: 2.0714 - accuracy: 0.1582 - val_loss: 2.0723 - val_accuracy: 0.1420
# Epoch 31/50
# 166/166 [==============================] - 8s 50ms/step - loss: 2.0718 - accuracy: 0.1572 - val_loss: 2.0717 - val_accuracy: 0.1616
# Epoch 32/50
# 166/166 [==============================] - 8s 49ms/step - loss: 2.0717 - accuracy: 0.1570 - val_loss: 2.0716 - val_accuracy: 0.1556
# ResNet50 测试准确率: 0.1881
# Epoch 1/50
# 166/166 [==============================] - 14s 62ms/step - loss: 2.0123 - accuracy: 0.2303 - val_loss: 1.7241 - val_accuracy: 0.3686
# Epoch 2/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.7253 - accuracy: 0.3401 - val_loss: 1.6203 - val_accuracy: 0.4131
# Epoch 3/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.6318 - accuracy: 0.3774 - val_loss: 1.5624 - val_accuracy: 0.4298
# Epoch 4/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.5638 - accuracy: 0.4159 - val_loss: 1.5171 - val_accuracy: 0.4479
# Epoch 5/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.5206 - accuracy: 0.4359 - val_loss: 1.4877 - val_accuracy: 0.4668
# Epoch 6/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.4999 - accuracy: 0.4477 - val_loss: 1.4590 - val_accuracy: 0.4728
# Epoch 7/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.4659 - accuracy: 0.4556 - val_loss: 1.4350 - val_accuracy: 0.4796
# Epoch 8/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.4297 - accuracy: 0.4707 - val_loss: 1.4138 - val_accuracy: 0.4796
# Epoch 9/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.4044 - accuracy: 0.4794 - val_loss: 1.3959 - val_accuracy: 0.4804
# Epoch 10/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.3874 - accuracy: 0.4934 - val_loss: 1.3783 - val_accuracy: 0.4932
# Epoch 11/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.3667 - accuracy: 0.5053 - val_loss: 1.3640 - val_accuracy: 0.4985
# Epoch 12/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.3553 - accuracy: 0.5042 - val_loss: 1.3510 - val_accuracy: 0.5076
# Epoch 13/50
# 166/166 [==============================] - 8s 51ms/step - loss: 1.3302 - accuracy: 0.5149 - val_loss: 1.3398 - val_accuracy: 0.5098
# Epoch 14/50
# 166/166 [==============================] - 9s 53ms/step - loss: 1.3166 - accuracy: 0.5189 - val_loss: 1.3303 - val_accuracy: 0.5159
# Epoch 15/50
# 166/166 [==============================] - 9s 54ms/step - loss: 1.2888 - accuracy: 0.5299 - val_loss: 1.3192 - val_accuracy: 0.5166
# Epoch 16/50
# 166/166 [==============================] - 9s 54ms/step - loss: 1.2842 - accuracy: 0.5374 - val_loss: 1.3087 - val_accuracy: 0.5310
# Epoch 17/50
# 166/166 [==============================] - 9s 53ms/step - loss: 1.2739 - accuracy: 0.5351 - val_loss: 1.3024 - val_accuracy: 0.5310
# Epoch 18/50
# 166/166 [==============================] - 9s 53ms/step - loss: 1.2643 - accuracy: 0.5391 - val_loss: 1.2952 - val_accuracy: 0.5317
# Epoch 19/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.2461 - accuracy: 0.5406 - val_loss: 1.2878 - val_accuracy: 0.5363
# Epoch 20/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.2472 - accuracy: 0.5557 - val_loss: 1.2824 - val_accuracy: 0.5332
# Epoch 21/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.2221 - accuracy: 0.5618 - val_loss: 1.2721 - val_accuracy: 0.5415
# Epoch 22/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.2244 - accuracy: 0.5561 - val_loss: 1.2684 - val_accuracy: 0.5340
# Epoch 23/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1996 - accuracy: 0.5688 - val_loss: 1.2613 - val_accuracy: 0.5393
# Epoch 24/50
# 166/166 [==============================] - 9s 51ms/step - loss: 1.1922 - accuracy: 0.5616 - val_loss: 1.2623 - val_accuracy: 0.5347
# Epoch 25/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1870 - accuracy: 0.5824 - val_loss: 1.2538 - val_accuracy: 0.5393
# Epoch 26/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1840 - accuracy: 0.5801 - val_loss: 1.2485 - val_accuracy: 0.5370
# Epoch 27/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1687 - accuracy: 0.5848 - val_loss: 1.2440 - val_accuracy: 0.5400
# Epoch 28/50
# 166/166 [==============================] - 9s 51ms/step - loss: 1.1606 - accuracy: 0.5852 - val_loss: 1.2395 - val_accuracy: 0.5415
# Epoch 29/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1546 - accuracy: 0.5873 - val_loss: 1.2377 - val_accuracy: 0.5363
# Epoch 30/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1431 - accuracy: 0.5888 - val_loss: 1.2345 - val_accuracy: 0.5415
# Epoch 31/50
# 166/166 [==============================] - 9s 51ms/step - loss: 1.1334 - accuracy: 0.5926 - val_loss: 1.2296 - val_accuracy: 0.5446
# Epoch 32/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1402 - accuracy: 0.5905 - val_loss: 1.2235 - val_accuracy: 0.5491
# Epoch 33/50
# 166/166 [==============================] - 9s 53ms/step - loss: 1.1232 - accuracy: 0.5926 - val_loss: 1.2190 - val_accuracy: 0.5476
# Epoch 34/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1168 - accuracy: 0.6005 - val_loss: 1.2173 - val_accuracy: 0.5468
# Epoch 35/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1130 - accuracy: 0.6041 - val_loss: 1.2166 - val_accuracy: 0.5468
# Epoch 36/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.1095 - accuracy: 0.5949 - val_loss: 1.2116 - val_accuracy: 0.5514
# Epoch 37/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0982 - accuracy: 0.5998 - val_loss: 1.2095 - val_accuracy: 0.5529
# Epoch 38/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0934 - accuracy: 0.6111 - val_loss: 1.2039 - val_accuracy: 0.5566
# Epoch 39/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0779 - accuracy: 0.6083 - val_loss: 1.2017 - val_accuracy: 0.5612
# Epoch 40/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0797 - accuracy: 0.6117 - val_loss: 1.1986 - val_accuracy: 0.5529
# Epoch 41/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0663 - accuracy: 0.6209 - val_loss: 1.1978 - val_accuracy: 0.5597
# Epoch 42/50
# 166/166 [==============================] - 9s 51ms/step - loss: 1.0653 - accuracy: 0.6198 - val_loss: 1.1977 - val_accuracy: 0.5566
# Epoch 43/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0494 - accuracy: 0.6266 - val_loss: 1.1925 - val_accuracy: 0.5574
# Epoch 44/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0559 - accuracy: 0.6219 - val_loss: 1.1890 - val_accuracy: 0.5551
# Epoch 45/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0481 - accuracy: 0.6253 - val_loss: 1.1866 - val_accuracy: 0.5574
# Epoch 46/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0474 - accuracy: 0.6247 - val_loss: 1.1848 - val_accuracy: 0.5634
# Epoch 47/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0395 - accuracy: 0.6279 - val_loss: 1.1834 - val_accuracy: 0.5619
# Epoch 48/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0306 - accuracy: 0.6315 - val_loss: 1.1824 - val_accuracy: 0.5597
# Epoch 49/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0302 - accuracy: 0.6338 - val_loss: 1.1806 - val_accuracy: 0.5627
# Epoch 50/50
# 166/166 [==============================] - 9s 52ms/step - loss: 1.0174 - accuracy: 0.6389 - val_loss: 1.1790 - val_accuracy: 0.5687
# DenseNet121 测试准确率: 0.5687
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/50
# 166/166 [==============================] - 6s 27ms/step - loss: 1.9632 - accuracy: 0.2549 - val_loss: 1.7081 - val_accuracy: 0.3731
# Epoch 2/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.7127 - accuracy: 0.3687 - val_loss: 1.5952 - val_accuracy: 0.4298
# Epoch 3/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.6177 - accuracy: 0.4017 - val_loss: 1.5318 - val_accuracy: 0.4441
# Epoch 4/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.5559 - accuracy: 0.4216 - val_loss: 1.4884 - val_accuracy: 0.4653
# Epoch 5/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.5013 - accuracy: 0.4531 - val_loss: 1.4494 - val_accuracy: 0.4789
# Epoch 6/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.4587 - accuracy: 0.4656 - val_loss: 1.4163 - val_accuracy: 0.4917
# Epoch 7/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.4168 - accuracy: 0.4796 - val_loss: 1.3962 - val_accuracy: 0.5000
# Epoch 8/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.3836 - accuracy: 0.4958 - val_loss: 1.3723 - val_accuracy: 0.5098
# Epoch 9/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.3448 - accuracy: 0.5200 - val_loss: 1.3568 - val_accuracy: 0.5068
# Epoch 10/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.3258 - accuracy: 0.5285 - val_loss: 1.3408 - val_accuracy: 0.5181
# Epoch 11/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.3033 - accuracy: 0.5293 - val_loss: 1.3246 - val_accuracy: 0.5189
# Epoch 12/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.2772 - accuracy: 0.5404 - val_loss: 1.3103 - val_accuracy: 0.5272
# Epoch 13/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.2523 - accuracy: 0.5497 - val_loss: 1.2976 - val_accuracy: 0.5378
# Epoch 14/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.2405 - accuracy: 0.5516 - val_loss: 1.2930 - val_accuracy: 0.5423
# Epoch 15/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.2205 - accuracy: 0.5652 - val_loss: 1.2774 - val_accuracy: 0.5491
# Epoch 16/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.1883 - accuracy: 0.5750 - val_loss: 1.2697 - val_accuracy: 0.5453
# Epoch 17/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.1735 - accuracy: 0.5769 - val_loss: 1.2637 - val_accuracy: 0.5438
# Epoch 18/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.1684 - accuracy: 0.5877 - val_loss: 1.2572 - val_accuracy: 0.5491
# Epoch 19/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.1450 - accuracy: 0.5854 - val_loss: 1.2497 - val_accuracy: 0.5400
# Epoch 20/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.1409 - accuracy: 0.5935 - val_loss: 1.2396 - val_accuracy: 0.5514
# Epoch 21/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.1303 - accuracy: 0.6017 - val_loss: 1.2362 - val_accuracy: 0.5461
# Epoch 22/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.1043 - accuracy: 0.6100 - val_loss: 1.2318 - val_accuracy: 0.5483
# Epoch 23/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.0897 - accuracy: 0.6141 - val_loss: 1.2188 - val_accuracy: 0.5529
# Epoch 24/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.0804 - accuracy: 0.6128 - val_loss: 1.2165 - val_accuracy: 0.5544
# Epoch 25/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.0685 - accuracy: 0.6175 - val_loss: 1.2143 - val_accuracy: 0.5453
# Epoch 26/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.0612 - accuracy: 0.6194 - val_loss: 1.2051 - val_accuracy: 0.5551
# Epoch 27/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.0465 - accuracy: 0.6321 - val_loss: 1.2058 - val_accuracy: 0.5551
# Epoch 28/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.0315 - accuracy: 0.6361 - val_loss: 1.1964 - val_accuracy: 0.5483
# Epoch 29/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.0205 - accuracy: 0.6353 - val_loss: 1.1942 - val_accuracy: 0.5589
# Epoch 30/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.0044 - accuracy: 0.6438 - val_loss: 1.1859 - val_accuracy: 0.5634
# Epoch 31/50
# 166/166 [==============================] - 4s 24ms/step - loss: 1.0020 - accuracy: 0.6470 - val_loss: 1.1946 - val_accuracy: 0.5498
# Epoch 32/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.9795 - accuracy: 0.6536 - val_loss: 1.1842 - val_accuracy: 0.5604
# Epoch 33/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.9752 - accuracy: 0.6568 - val_loss: 1.1800 - val_accuracy: 0.5634
# Epoch 34/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.9637 - accuracy: 0.6602 - val_loss: 1.1799 - val_accuracy: 0.5657
# Epoch 35/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.9558 - accuracy: 0.6574 - val_loss: 1.1784 - val_accuracy: 0.5702
# Epoch 36/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.9470 - accuracy: 0.6742 - val_loss: 1.1727 - val_accuracy: 0.5680
# Epoch 37/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.9375 - accuracy: 0.6697 - val_loss: 1.1669 - val_accuracy: 0.5785
# Epoch 38/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.9302 - accuracy: 0.6687 - val_loss: 1.1634 - val_accuracy: 0.5755
# Epoch 39/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.9135 - accuracy: 0.6831 - val_loss: 1.1623 - val_accuracy: 0.5816
# Epoch 40/50
# 166/166 [==============================] - 4s 25ms/step - loss: 0.9030 - accuracy: 0.6876 - val_loss: 1.1608 - val_accuracy: 0.5680
# Epoch 41/50
# 166/166 [==============================] - 4s 25ms/step - loss: 0.8979 - accuracy: 0.6867 - val_loss: 1.1608 - val_accuracy: 0.5748
# Epoch 42/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.8893 - accuracy: 0.6903 - val_loss: 1.1525 - val_accuracy: 0.5808
# Epoch 43/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.8879 - accuracy: 0.6918 - val_loss: 1.1537 - val_accuracy: 0.5853
# Epoch 44/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.8806 - accuracy: 0.6907 - val_loss: 1.1504 - val_accuracy: 0.5793
# Epoch 45/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.8695 - accuracy: 0.6952 - val_loss: 1.1460 - val_accuracy: 0.5838
# Epoch 46/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.8562 - accuracy: 0.7099 - val_loss: 1.1471 - val_accuracy: 0.5891
# Epoch 47/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.8455 - accuracy: 0.7045 - val_loss: 1.1487 - val_accuracy: 0.5838
# Epoch 48/50
# 166/166 [==============================] - 4s 25ms/step - loss: 0.8364 - accuracy: 0.7099 - val_loss: 1.1430 - val_accuracy: 0.5793
# Epoch 49/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.8353 - accuracy: 0.7065 - val_loss: 1.1441 - val_accuracy: 0.5838
# Epoch 50/50
# 166/166 [==============================] - 4s 24ms/step - loss: 0.8128 - accuracy: 0.7215 - val_loss: 1.1483 - val_accuracy: 0.5801
# MobileNetV2 测试准确率: 0.5801

# %%
from numba import cuda

cuda.select_device(0)
cuda.close()
