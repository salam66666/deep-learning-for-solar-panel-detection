# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# 配置参数
ORIGINAL_HEIGHT = 24
ORIGINAL_WIDTH = 40
TARGET_HEIGHT = 128
TARGET_WIDTH = int(ORIGINAL_WIDTH * (TARGET_HEIGHT / ORIGINAL_HEIGHT))  # 213
BATCH_SIZE = 32
NUM_CLASSES = 2
EPOCHS = 50
SEED = 42

DATASET_DIR = r"E:\CDUT\English\7 Term\Project\model\archive\panel_cell"  # 改为2分类数据目录（包含detected和non-detected）

# Inception模块
class InceptionModule(layers.Layer):
    def __init__(self, filters, name="inception_block", **kwargs):
        super().__init__(name=name, **kwargs)
        self.filters = filters
        self.branch1 = models.Sequential([
            layers.Conv2D(filters[0], (1, 1), padding='same', activation='relu')
        ])
        self.branch2 = models.Sequential([
            layers.Conv2D(filters[1], (1, 1), padding='same', activation='relu'),
            layers.Conv2D(filters[2], (3, 3), padding='same', activation='relu')
        ])
        self.branch3 = models.Sequential([
            layers.Conv2D(filters[3], (1, 1), padding='same', activation='relu'),
            layers.Conv2D(filters[4], (5, 5), padding='same', activation='relu')
        ])
        self.branch4 = models.Sequential([
            layers.MaxPooling2D((3, 3), strides=(1, 1), padding='same'),
            layers.Conv2D(filters[5], (1, 1), padding='same', activation='relu')
        ])
    def call(self, inputs):
        return layers.concatenate([
            self.branch1(inputs),
            self.branch2(inputs),
            self.branch3(inputs),
            self.branch4(inputs)
        ], axis=-1)
    def get_config(self):
        config = super().get_config()
        config.update({'filters': self.filters})
        return config

# 多头注意力模块
class MultiHeadAttention(layers.Layer):
    def __init__(self, num_heads, key_dim, name="multihead_attn", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_heads = num_heads
        self.key_dim = key_dim
        self.Wq = layers.Dense(key_dim * num_heads)
        self.Wk = layers.Dense(key_dim * num_heads)
        self.Wv = layers.Dense(key_dim * num_heads)
        self.dense = layers.Dense(key_dim * num_heads)

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        Q = tf.reshape(self.Wq(inputs), [batch_size, -1, self.num_heads, self.key_dim])
        K = tf.reshape(self.Wk(inputs), [batch_size, -1, self.num_heads, self.key_dim])
        V = tf.reshape(self.Wv(inputs), [batch_size, -1, self.num_heads, self.key_dim])
        attention = tf.einsum('bqhd,bkhd->bhqk', Q, K) / tf.sqrt(tf.cast(self.key_dim, tf.float32))
        attention = tf.nn.softmax(attention, axis=-1)
        output = tf.einsum('bhqk,bkhd->bqhd', attention, V)
        output = tf.reshape(output, [batch_size, -1, self.num_heads * self.key_dim])
        return self.dense(output), attention

    def get_config(self):
        return {'num_heads': self.num_heads, 'key_dim': self.key_dim}

# 构建模型
def build_model():
    inputs = layers.Input(shape=(TARGET_HEIGHT, TARGET_WIDTH, 3))
    x = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    x = InceptionModule([16, 16, 32, 16, 32, 16])(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Reshape((64, 106 * 96))(x)
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.Dropout(0.3)(x)
    attn_output, _ = MultiHeadAttention(num_heads=4, key_dim=32)(x)
    x = layers.Concatenate()([x, attn_output])
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return models.Model(inputs, outputs)

# 加载图像与标签
def prepare_datasets(root_dir):
    image_paths, labels = [], []
    for idx, class_name in enumerate(['non-detected', 'detected']):
        class_dir = os.path.join(root_dir, class_name)
        for fname in os.listdir(class_dir):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(class_dir, fname))
                labels.append(idx)
    return image_paths, np.array(labels)

# 图像预处理（保持一致）
def preprocess_image(image, augment=False):
    image = tf.image.resize(image, [TARGET_HEIGHT, TARGET_WIDTH], method=tf.image.ResizeMethod.BICUBIC)
    image = tf.cast(image, tf.float32) / 255.0
    if augment:
        image = tf.image.random_brightness(image, max_delta=0.1)
        image = tf.image.random_contrast(image, lower=0.9, upper=1.1)
    return image

def create_dataset(image_paths, labels, augment=False):
    def parse_fn(path, label):
        image = tf.io.decode_jpeg(tf.io.read_file(path), channels=3)
        return preprocess_image(image, augment), label
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(parse_fn, num_parallel_calls=tf.data.AUTOTUNE)
    return dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# 主程序
if __name__ == "__main__":
    image_paths, labels = prepare_datasets(DATASET_DIR)
    X_train, X_test, y_train, y_test = train_test_split(image_paths, labels, test_size=0.2, stratify=labels, random_state=SEED)
    train_dataset = create_dataset(X_train, y_train, augment=True)
    test_dataset = create_dataset(X_test, y_test, augment=False)

    model = build_model()
    model.compile(
        optimizer=optimizers.Adam(learning_rate=1e-4),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    model.summary()

    class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights = dict(enumerate(class_weights))

    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_accuracy', restore_best_weights=True),
        tf.keras.callbacks.ModelCheckpoint("best_binary_model.h5", save_best_only=True, monitor='val_accuracy'),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    ]

    history = model.fit(
        train_dataset,
        validation_data=test_dataset,
        epochs=EPOCHS,
        class_weight=class_weights,
        callbacks=callbacks
    )

    model.save("final_binary_model.h5")

    # 绘图
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # 评估
    y_pred = (model.predict(test_dataset) > 0.5).astype("int32")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, target_names=['non-detected', 'detected']))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 213, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 213, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 213, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# inception_block (InceptionModul (None, 128, 213, 96) 19584       batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 106, 96)  0           inception_block[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64, 10176)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 64, 256)      10552320    reshape[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64, 256)      0           bidirectional[0][0]
# __________________________________________________________________________________________________
# multihead_attn (MultiHeadAttent ((None, None, 128),  115200      dropout[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 384)      0           dropout[0][0]
#                                                                  multihead_attn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 384)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          98560       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 10,786,945
# Trainable params: 10,786,881
# Non-trainable params: 64
# __________________________________________________________________________________________________
# Epoch 1/50
# 500/500 [==============================] - 56s 96ms/step - loss: 0.5883 - accuracy: 0.6758 - val_loss: 0.4666 - val_accuracy: 0.7782
# Epoch 2/50
# 500/500 [==============================] - 50s 100ms/step - loss: 0.4359 - accuracy: 0.8000 - val_loss: 0.4044 - val_accuracy: 0.8167
# Epoch 3/50
# 500/500 [==============================] - 51s 102ms/step - loss: 0.3979 - accuracy: 0.8269 - val_loss: 0.3748 - val_accuracy: 0.8440
# Epoch 4/50
# 500/500 [==============================] - 51s 102ms/step - loss: 0.3762 - accuracy: 0.8379 - val_loss: 0.3648 - val_accuracy: 0.8472
# Epoch 5/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.3592 - accuracy: 0.8451 - val_loss: 0.3635 - val_accuracy: 0.8518
# Epoch 6/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.3440 - accuracy: 0.8551 - val_loss: 0.3418 - val_accuracy: 0.8633
# Epoch 7/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.3343 - accuracy: 0.8593 - val_loss: 0.3390 - val_accuracy: 0.8562
# Epoch 8/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.3228 - accuracy: 0.8649 - val_loss: 0.3218 - val_accuracy: 0.8675
# Epoch 9/50
# 500/500 [==============================] - 52s 103ms/step - loss: 0.3136 - accuracy: 0.8677 - val_loss: 0.3156 - val_accuracy: 0.8725
# Epoch 10/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.2990 - accuracy: 0.8753 - val_loss: 0.3225 - val_accuracy: 0.8700
# Epoch 11/50
# 500/500 [==============================] - 52s 103ms/step - loss: 0.2928 - accuracy: 0.8789 - val_loss: 0.3123 - val_accuracy: 0.8765
# Epoch 12/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.2852 - accuracy: 0.8833 - val_loss: 0.3222 - val_accuracy: 0.8700
# Epoch 13/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.2754 - accuracy: 0.8869 - val_loss: 0.3232 - val_accuracy: 0.8755
# Epoch 14/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.2654 - accuracy: 0.8907 - val_loss: 0.3185 - val_accuracy: 0.8760
# Epoch 15/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.2585 - accuracy: 0.8966 - val_loss: 0.3190 - val_accuracy: 0.8767
# Epoch 16/50
# 500/500 [==============================] - 52s 103ms/step - loss: 0.2521 - accuracy: 0.8986 - val_loss: 0.3163 - val_accuracy: 0.8760
# Epoch 17/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.2209 - accuracy: 0.9114 - val_loss: 0.3020 - val_accuracy: 0.8885
# Epoch 18/50
# 500/500 [==============================] - 54s 107ms/step - loss: 0.2070 - accuracy: 0.9209 - val_loss: 0.3283 - val_accuracy: 0.8830
# Epoch 19/50
# 500/500 [==============================] - 52s 105ms/step - loss: 0.1977 - accuracy: 0.9228 - val_loss: 0.3221 - val_accuracy: 0.8860
# Epoch 20/50
# 500/500 [==============================] - 53s 105ms/step - loss: 0.1918 - accuracy: 0.9266 - val_loss: 0.3176 - val_accuracy: 0.8860
# Epoch 21/50
# 500/500 [==============================] - 53s 105ms/step - loss: 0.1842 - accuracy: 0.9298 - val_loss: 0.3178 - val_accuracy: 0.8878
# Epoch 22/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.1754 - accuracy: 0.9329 - val_loss: 0.3237 - val_accuracy: 0.8920
# Epoch 23/50
# 500/500 [==============================] - 52s 103ms/step - loss: 0.1602 - accuracy: 0.9402 - val_loss: 0.3241 - val_accuracy: 0.8925
# Epoch 24/50
# 500/500 [==============================] - 52s 103ms/step - loss: 0.1465 - accuracy: 0.9461 - val_loss: 0.3297 - val_accuracy: 0.8920
# Epoch 25/50
# 500/500 [==============================] - 52s 103ms/step - loss: 0.1435 - accuracy: 0.9454 - val_loss: 0.3353 - val_accuracy: 0.8932
# Epoch 26/50
# 500/500 [==============================] - 53s 106ms/step - loss: 0.1394 - accuracy: 0.9478 - val_loss: 0.3506 - val_accuracy: 0.8923
# Epoch 27/50
# 500/500 [==============================] - 62s 124ms/step - loss: 0.1281 - accuracy: 0.9509 - val_loss: 0.3569 - val_accuracy: 0.8928
# Epoch 28/50
# 500/500 [==============================] - 54s 107ms/step - loss: 0.1211 - accuracy: 0.9551 - val_loss: 0.3402 - val_accuracy: 0.8940
# Epoch 29/50
# 500/500 [==============================] - 53s 105ms/step - loss: 0.1138 - accuracy: 0.9574 - val_loss: 0.3449 - val_accuracy: 0.8947
# Epoch 30/50
# 500/500 [==============================] - 52s 105ms/step - loss: 0.1127 - accuracy: 0.9582 - val_loss: 0.3468 - val_accuracy: 0.8940
# Epoch 31/50
# 500/500 [==============================] - 53s 105ms/step - loss: 0.1094 - accuracy: 0.9581 - val_loss: 0.3532 - val_accuracy: 0.8930
# Epoch 32/50
# 500/500 [==============================] - 52s 104ms/step - loss: 0.1080 - accuracy: 0.9601 - val_loss: 0.3534 - val_accuracy: 0.8923
# Epoch 33/50
# 500/500 [==============================] - 53s 105ms/step - loss: 0.1001 - accuracy: 0.9636 - val_loss: 0.3487 - val_accuracy: 0.8965
# Epoch 34/50
# 500/500 [==============================] - 52s 105ms/step - loss: 0.0981 - accuracy: 0.9641 - val_loss: 0.3581 - val_accuracy: 0.8955
# Epoch 35/50
# 500/500 [==============================] - 53s 105ms/step - loss: 0.0943 - accuracy: 0.9650 - val_loss: 0.3588 - val_accuracy: 0.8945
# Epoch 36/50
# 500/500 [==============================] - 53s 105ms/step - loss: 0.0969 - accuracy: 0.9639 - val_loss: 0.3611 - val_accuracy: 0.8942
# Epoch 37/50
# 500/500 [==============================] - 52s 105ms/step - loss: 0.0913 - accuracy: 0.9675 - val_loss: 0.3635 - val_accuracy: 0.8932
# Epoch 38/50
# 500/500 [==============================] - 52s 105ms/step - loss: 0.0866 - accuracy: 0.9693 - val_loss: 0.3661 - val_accuracy: 0.8950
# Epoch 39/50
# 500/500 [==============================] - 53s 105ms/step - loss: 0.0873 - accuracy: 0.9676 - val_loss: 0.3662 - val_accuracy: 0.8965
# Epoch 40/50
# 500/500 [==============================] - 53s 106ms/step - loss: 0.0872 - accuracy: 0.9685 - val_loss: 0.3696 - val_accuracy: 0.8957
# Epoch 41/50
# 500/500 [==============================] - 52s 105ms/step - loss: 0.0862 - accuracy: 0.9689 - val_loss: 0.3707 - val_accuracy: 0.8953
# Epoch 42/50
# 500/500 [==============================] - 52s 105ms/step - loss: 0.0846 - accuracy: 0.9691 - val_loss: 0.3763 - val_accuracy: 0.8957
# Epoch 43/50
# 500/500 [==============================] - 53s 105ms/step - loss: 0.0852 - accuracy: 0.9689 - val_loss: 0.3757 - val_accuracy: 0.8965
# Classification Report:
#               precision    recall  f1-score   support
#
# non-detected       0.86      0.94      0.90      2000
#     detected       0.94      0.85      0.89      2000
#
#     accuracy                           0.90      4000
#    macro avg       0.90      0.90      0.90      4000
# weighted avg       0.90      0.90      0.90      4000

# %%
import matplotlib.pyplot as plt

# 添加预处理可视化检查
test_image = next(iter(train_dataset.take(1)))[0][0]
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("Original (24x40)")
plt.imshow(tf.image.resize(test_image, (24,40)))
plt.subplot(1,2,2)
plt.title("Scaled (128x213)")
plt.imshow(test_image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def plot_binary_class_distribution(y_train, y_test, class_names=['non-detected', 'detected']):
    train_counts = np.bincount(y_train, minlength=2)
    test_counts = np.bincount(y_test, minlength=2)

    bar_width = 0.35
    index = np.arange(2)

    plt.figure(figsize=(8, 6))
    bars_train = plt.bar(index - bar_width/2, train_counts, bar_width, label='Train', color='#1f77b4')
    bars_test = plt.bar(index + bar_width/2, test_counts, bar_width, label='Validation', color='#ff7f0e')

    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2., height,
                     f'{int(height)}', ha='center', va='bottom', fontsize=10)

    add_labels(bars_train)
    add_labels(bars_test)

    plt.title('Class Distribution (Binary Classification)', fontsize=14)
    plt.xlabel('Defect Type', fontsize=12)
    plt.ylabel('Number of Samples', fontsize=12)
    plt.xticks(index, class_names)
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.3)
    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    image_paths, labels = prepare_datasets(DATASET_DIR)
    X_train, X_test, y_train, y_test = train_test_split(image_paths, labels, test_size=0.2, stratify=labels, random_state=SEED)

    # === 可视化类别分布 ===
    plot_binary_class_distribution(y_train, y_test)

# %%
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    f1_score,
    accuracy_score,
    precision_score,
    recall_score,
    precision_recall_curve,
    average_precision_score
)
import seaborn as sns

# 设置类别名
class_names = ['non-detected', 'detected']

# 获取预测概率
y_pred_probs = model.predict(test_dataset).flatten()
y_pred = (y_pred_probs > 0.5).astype(int)

# 获取真实标签
y_true = np.concatenate([y.numpy() for _, y in test_dataset], axis=0)

# 打印预测样本
print("\nSample predictions comparison:")
print("Predicted labels:", y_pred[:10])
print("True labels:     ", y_true[:10])

# 混淆矩阵
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label", fontsize=12)
plt.ylabel("True Label", fontsize=12)
plt.title("Confusion Matrix", fontsize=14)
plt.tight_layout()
plt.show()

# ROC曲线
fpr, tpr, _ = roc_curve(y_true, y_pred_probs)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)
plt.title("ROC Curve", fontsize=14)
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# PR曲线
precision, recall, _ = precision_recall_curve(y_true, y_pred_probs)
ap = average_precision_score(y_true, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(recall, precision, color='purple', lw=2, label=f"PR Curve (AP = {ap:.2f})")
plt.xlabel("Recall", fontsize=12)
plt.ylabel("Precision", fontsize=12)
plt.title("Precision-Recall Curve", fontsize=14)
plt.legend(loc="lower left")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# 核心指标输出
print("\nKey Metrics:")
print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
print(f"Precision: {precision_score(y_true, y_pred):.4f}")
print(f"Recall: {recall_score(y_true, y_pred):.4f}")
print(f"F1 Score: {f1_score(y_true, y_pred):.4f}")
print(f"Average Precision (AP): {ap:.4f}")

# 分类报告
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
# Out:
# Sample predictions comparison:
# Predicted labels: [0 0 0 1 0 0 1 0 1 1]
# True labels:      [1 0 0 1 0 0 1 0 1 1]
# Key Metrics:
# Accuracy: 0.8965
# Precision: 0.9367
# Recall: 0.8505
# F1 Score: 0.8915
# Average Precision (AP): 0.9613
#
# Classification Report:
#               precision    recall  f1-score   support
#
# non-detected     0.8631    0.9425    0.9011      2000
#     detected     0.9367    0.8505    0.8915      2000
#
#     accuracy                         0.8965      4000
#    macro avg     0.8999    0.8965    0.8963      4000
# weighted avg     0.8999    0.8965    0.8963      4000

# %%
from numba import cuda

cuda.select_device(0)
cuda.close()
