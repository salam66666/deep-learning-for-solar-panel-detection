# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# 配置参数
ORIGINAL_HEIGHT = 24
ORIGINAL_WIDTH = 40
TARGET_HEIGHT = 128
TARGET_WIDTH = int(ORIGINAL_WIDTH * (TARGET_HEIGHT / ORIGINAL_HEIGHT))  # 213
BATCH_SIZE = 32
NUM_CLASSES = 2
EPOCHS = 50
SEED = 42

DATASET_DIR = r"E:\CDUT\English\7 Term\Project\model\archive\panel_cell"  # 改为2分类数据目录（包含detected和non-detected）

# Inception模块
class InceptionModule(layers.Layer):
    def __init__(self, filters, name="inception_block", **kwargs):
        super().__init__(name=name, **kwargs)
        self.filters = filters
        self.branch1 = models.Sequential([
            layers.Conv2D(filters[0], (1, 1), padding='same', activation='relu')
        ])
        self.branch2 = models.Sequential([
            layers.Conv2D(filters[1], (1, 1), padding='same', activation='relu'),
            layers.Conv2D(filters[2], (3, 3), padding='same', activation='relu')
        ])
        self.branch3 = models.Sequential([
            layers.Conv2D(filters[3], (1, 1), padding='same', activation='relu'),
            layers.Conv2D(filters[4], (5, 5), padding='same', activation='relu')
        ])
        self.branch4 = models.Sequential([
            layers.MaxPooling2D((3, 3), strides=(1, 1), padding='same'),
            layers.Conv2D(filters[5], (1, 1), padding='same', activation='relu')
        ])
    def call(self, inputs):
        return layers.concatenate([
            self.branch1(inputs),
            self.branch2(inputs),
            self.branch3(inputs),
            self.branch4(inputs)
        ], axis=-1)
    def get_config(self):
        config = super().get_config()
        config.update({'filters': self.filters})
        return config

# 多头注意力模块
class MultiHeadAttention(layers.Layer):
    def __init__(self, num_heads, key_dim, name="multihead_attn", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_heads = num_heads
        self.key_dim = key_dim
        self.Wq = layers.Dense(key_dim * num_heads)
        self.Wk = layers.Dense(key_dim * num_heads)
        self.Wv = layers.Dense(key_dim * num_heads)
        self.dense = layers.Dense(key_dim * num_heads)

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        Q = tf.reshape(self.Wq(inputs), [batch_size, -1, self.num_heads, self.key_dim])
        K = tf.reshape(self.Wk(inputs), [batch_size, -1, self.num_heads, self.key_dim])
        V = tf.reshape(self.Wv(inputs), [batch_size, -1, self.num_heads, self.key_dim])
        attention = tf.einsum('bqhd,bkhd->bhqk', Q, K) / tf.sqrt(tf.cast(self.key_dim, tf.float32))
        attention = tf.nn.softmax(attention, axis=-1)
        output = tf.einsum('bhqk,bkhd->bqhd', attention, V)
        output = tf.reshape(output, [batch_size, -1, self.num_heads * self.key_dim])
        return self.dense(output), attention

    def get_config(self):
        return {'num_heads': self.num_heads, 'key_dim': self.key_dim}

def build_model():
    inputs = layers.Input(shape=(TARGET_HEIGHT, TARGET_WIDTH, 3))

    x = layers.Conv2D(16, (3, 3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(1e-2))(inputs)  # Reduced filters
    x = layers.BatchNormalization()(x)

    x = InceptionModule([8, 8, 16, 8, 16, 8])(x)  # Reduced filters in Inception module
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Reshape((64, -1))(x) # Dynamically calculate the last dimension


    x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)  # Reduced LSTM units
    x = layers.Dropout(0.5)(x)  # Dropout - experiment with values

    attn_output, _ = MultiHeadAttention(num_heads=2, key_dim=16)(x)  # Reduced heads and key dimension
    x = layers.Concatenate()([x, attn_output])  # Attention mechanism kept

    x = layers.GlobalAveragePooling1D()(x)

    x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)  # Reduced units
    x = layers.Dropout(0.3)(x)  # Dropout - experiment with values
    outputs = layers.Dense(1, activation='sigmoid')(x)

    return models.Model(inputs, outputs)

# 加载图像与标签
def prepare_datasets(root_dir):
    image_paths, labels = [], []
    for idx, class_name in enumerate(['non-detected', 'detected']):
        class_dir = os.path.join(root_dir, class_name)
        for fname in os.listdir(class_dir):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(class_dir, fname))
                labels.append(idx)
    return image_paths, np.array(labels)

# 图像预处理（保持一致）
def preprocess_image(image, augment=False):
    image = tf.image.resize(image, [TARGET_HEIGHT, TARGET_WIDTH], method=tf.image.ResizeMethod.BICUBIC)
    image = tf.cast(image, tf.float32) / 255.0
    if augment:
        image = tf.image.random_brightness(image, max_delta=0.1)
        image = tf.image.random_contrast(image, lower=0.9, upper=1.1)
    return image

def create_dataset(image_paths, labels, augment=False):
    def parse_fn(path, label):
        image = tf.io.decode_jpeg(tf.io.read_file(path), channels=3)
        return preprocess_image(image, augment), label
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(parse_fn, num_parallel_calls=tf.data.AUTOTUNE)
    return dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# 主程序
if __name__ == "__main__":
    image_paths, labels = prepare_datasets(DATASET_DIR)
    X_train, X_test, y_train, y_test = train_test_split(image_paths, labels, test_size=0.2, stratify=labels, random_state=SEED)
    train_dataset = create_dataset(X_train, y_train, augment=True)
    test_dataset = create_dataset(X_test, y_test, augment=False)

    model = build_model()
    model.compile(
        optimizer=optimizers.Adam(learning_rate=1e-4),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    model.summary()

    class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights = dict(enumerate(class_weights))

    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_accuracy', restore_best_weights=True),
        tf.keras.callbacks.ModelCheckpoint("best_binary_model2.h5", save_best_only=True, monitor='val_accuracy'),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    ]

    history = model.fit(
        train_dataset,
        validation_data=test_dataset,
        epochs=EPOCHS,
        class_weight=class_weights,
        callbacks=callbacks
    )

    model.save("final_binary_model2.h5")

    # 绘图
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # 评估
    y_pred = (model.predict(test_dataset) > 0.5).astype("int32")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, target_names=['non-detected', 'detected']))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 213, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 213, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 213, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# inception_block (InceptionModul (None, 128, 213, 48) 4928        batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 106, 48)  0           inception_block[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64, 5088)     0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 64, 128)      2638336     reshape[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64, 128)      0           bidirectional[0][0]
# __________________________________________________________________________________________________
# multihead_attn (MultiHeadAttent ((None, None, 32), ( 13440       dropout[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 160)      0           dropout[0][0]
#                                                                  multihead_attn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 160)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          20608       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            129         dropout_1[0][0]
# ==================================================================================================
# Total params: 2,677,953
# Trainable params: 2,677,921
# Non-trainable params: 32
# __________________________________________________________________________________________________
# Epoch 1/50
# 500/500 [==============================] - 42s 74ms/step - loss: 0.6724 - accuracy: 0.6614 - val_loss: 0.5761 - val_accuracy: 0.7542
# Epoch 2/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.5189 - accuracy: 0.7779 - val_loss: 0.4751 - val_accuracy: 0.8090
# Epoch 3/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.4591 - accuracy: 0.8148 - val_loss: 0.4377 - val_accuracy: 0.8265
# Epoch 4/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.4338 - accuracy: 0.8298 - val_loss: 0.4112 - val_accuracy: 0.8418
# Epoch 5/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.4151 - accuracy: 0.8382 - val_loss: 0.4015 - val_accuracy: 0.8518
# Epoch 6/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.4019 - accuracy: 0.8473 - val_loss: 0.4083 - val_accuracy: 0.8518
# Epoch 7/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3919 - accuracy: 0.8519 - val_loss: 0.3898 - val_accuracy: 0.8543
# Epoch 8/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3796 - accuracy: 0.8571 - val_loss: 0.3812 - val_accuracy: 0.8602
# Epoch 9/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3759 - accuracy: 0.8583 - val_loss: 0.3783 - val_accuracy: 0.8605
# Epoch 10/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3642 - accuracy: 0.8639 - val_loss: 0.3811 - val_accuracy: 0.8550
# Epoch 11/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3550 - accuracy: 0.8691 - val_loss: 0.3771 - val_accuracy: 0.8577
# Epoch 12/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3502 - accuracy: 0.8715 - val_loss: 0.3591 - val_accuracy: 0.8680
# Epoch 13/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3406 - accuracy: 0.8748 - val_loss: 0.3540 - val_accuracy: 0.8735
# Epoch 14/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3333 - accuracy: 0.8783 - val_loss: 0.3642 - val_accuracy: 0.8723
# Epoch 15/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3288 - accuracy: 0.8776 - val_loss: 0.3629 - val_accuracy: 0.8715
# Epoch 16/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3226 - accuracy: 0.8827 - val_loss: 0.3479 - val_accuracy: 0.8740
# Epoch 17/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3146 - accuracy: 0.8858 - val_loss: 0.3447 - val_accuracy: 0.8770
# Epoch 18/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3090 - accuracy: 0.8876 - val_loss: 0.3467 - val_accuracy: 0.8773
# Epoch 19/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.3030 - accuracy: 0.8892 - val_loss: 0.3675 - val_accuracy: 0.8683
# Epoch 20/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2957 - accuracy: 0.8921 - val_loss: 0.3470 - val_accuracy: 0.8752
# Epoch 21/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2906 - accuracy: 0.8938 - val_loss: 0.3471 - val_accuracy: 0.8750
# Epoch 22/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2877 - accuracy: 0.8959 - val_loss: 0.3332 - val_accuracy: 0.8790
# Epoch 23/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2780 - accuracy: 0.9014 - val_loss: 0.3401 - val_accuracy: 0.8767
# Epoch 24/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2752 - accuracy: 0.9036 - val_loss: 0.3371 - val_accuracy: 0.8780
# Epoch 25/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2693 - accuracy: 0.9068 - val_loss: 0.3380 - val_accuracy: 0.8820
# Epoch 26/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2615 - accuracy: 0.9084 - val_loss: 0.3580 - val_accuracy: 0.8735
# Epoch 27/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2575 - accuracy: 0.9108 - val_loss: 0.3565 - val_accuracy: 0.8708
# Epoch 28/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2390 - accuracy: 0.9196 - val_loss: 0.3439 - val_accuracy: 0.8813
# Epoch 29/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2292 - accuracy: 0.9247 - val_loss: 0.3359 - val_accuracy: 0.8823
# Epoch 30/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2236 - accuracy: 0.9251 - val_loss: 0.3420 - val_accuracy: 0.8810
# Epoch 31/50
# 500/500 [==============================] - 38s 77ms/step - loss: 0.2196 - accuracy: 0.9258 - val_loss: 0.3338 - val_accuracy: 0.8860
# Epoch 32/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2174 - accuracy: 0.9273 - val_loss: 0.3484 - val_accuracy: 0.8780
# Epoch 33/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.2043 - accuracy: 0.9340 - val_loss: 0.3381 - val_accuracy: 0.8855
# Epoch 34/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1949 - accuracy: 0.9381 - val_loss: 0.3365 - val_accuracy: 0.8885
# Epoch 35/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1940 - accuracy: 0.9385 - val_loss: 0.3381 - val_accuracy: 0.8880
# Epoch 36/50
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1896 - accuracy: 0.9404 - val_loss: 0.3306 - val_accuracy: 0.8885
# Epoch 37/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1907 - accuracy: 0.9389 - val_loss: 0.3395 - val_accuracy: 0.8878
# Epoch 38/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1870 - accuracy: 0.9395 - val_loss: 0.3435 - val_accuracy: 0.8910
# Epoch 39/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1870 - accuracy: 0.9415 - val_loss: 0.3464 - val_accuracy: 0.8865
# Epoch 40/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1794 - accuracy: 0.9437 - val_loss: 0.3522 - val_accuracy: 0.8875
# Epoch 41/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1776 - accuracy: 0.9431 - val_loss: 0.3476 - val_accuracy: 0.8890
# Epoch 42/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1724 - accuracy: 0.9448 - val_loss: 0.3386 - val_accuracy: 0.8910
# Epoch 43/50
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1717 - accuracy: 0.9474 - val_loss: 0.3398 - val_accuracy: 0.8907
# Classification Report:
#               precision    recall  f1-score   support
#
# non-detected       0.85      0.94      0.90      2000
#     detected       0.94      0.84      0.88      2000
#
#     accuracy                           0.89      4000
#    macro avg       0.90      0.89      0.89      4000
# weighted avg       0.90      0.89      0.89      4000

# %%
import matplotlib.pyplot as plt

# 添加预处理可视化检查
test_image = next(iter(train_dataset.take(1)))[0][0]
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("Original (24x40)")
plt.imshow(tf.image.resize(test_image, (24,40)))
plt.subplot(1,2,2)
plt.title("Scaled (128x213)")
plt.imshow(test_image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def plot_binary_class_distribution(y_train, y_test, class_names=['non-detected', 'detected']):
    train_counts = np.bincount(y_train, minlength=2)
    test_counts = np.bincount(y_test, minlength=2)

    bar_width = 0.35
    index = np.arange(2)

    plt.figure(figsize=(8, 6))
    bars_train = plt.bar(index - bar_width/2, train_counts, bar_width, label='Train', color='#1f77b4')
    bars_test = plt.bar(index + bar_width/2, test_counts, bar_width, label='Validation', color='#ff7f0e')

    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2., height,
                     f'{int(height)}', ha='center', va='bottom', fontsize=10)

    add_labels(bars_train)
    add_labels(bars_test)

    plt.title('Class Distribution (Binary Classification)', fontsize=14)
    plt.xlabel('Defect Type', fontsize=12)
    plt.ylabel('Number of Samples', fontsize=12)
    plt.xticks(index, class_names)
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.3)
    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    image_paths, labels = prepare_datasets(DATASET_DIR)
    X_train, X_test, y_train, y_test = train_test_split(image_paths, labels, test_size=0.2, stratify=labels, random_state=SEED)

    # === 可视化类别分布 ===
    plot_binary_class_distribution(y_train, y_test)

# %%
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    f1_score,
    accuracy_score,
    precision_score,
    recall_score,
    precision_recall_curve,
    average_precision_score
)
import seaborn as sns

# 设置类别名
class_names = ['non-detected', 'detected']

# 获取预测概率
y_pred_probs = model.predict(test_dataset).flatten()
y_pred = (y_pred_probs > 0.5).astype(int)

# 获取真实标签
y_true = np.concatenate([y.numpy() for _, y in test_dataset], axis=0)

# 打印预测样本
print("\nSample predictions comparison:")
print("Predicted labels:", y_pred[:10])
print("True labels:     ", y_true[:10])

# 混淆矩阵
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label", fontsize=12)
plt.ylabel("True Label", fontsize=12)
plt.title("Confusion Matrix", fontsize=14)
plt.tight_layout()
plt.show()

# ROC曲线
fpr, tpr, _ = roc_curve(y_true, y_pred_probs)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)
plt.title("ROC Curve", fontsize=14)
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# PR曲线
precision, recall, _ = precision_recall_curve(y_true, y_pred_probs)
ap = average_precision_score(y_true, y_pred_probs)
plt.figure(figsize=(6, 5))
plt.plot(recall, precision, color='purple', lw=2, label=f"PR Curve (AP = {ap:.2f})")
plt.xlabel("Recall", fontsize=12)
plt.ylabel("Precision", fontsize=12)
plt.title("Precision-Recall Curve", fontsize=14)
plt.legend(loc="lower left")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# 核心指标输出
print("\nKey Metrics:")
print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
print(f"Precision: {precision_score(y_true, y_pred):.4f}")
print(f"Recall: {recall_score(y_true, y_pred):.4f}")
print(f"F1 Score: {f1_score(y_true, y_pred):.4f}")
print(f"Average Precision (AP): {ap:.4f}")

# 分类报告
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
# Out:
# Sample predictions comparison:
# Predicted labels: [1 0 0 0 0 0 1 0 1 1]
# True labels:      [1 0 0 1 0 0 1 0 1 1]
# Key Metrics:
# Accuracy: 0.8910
# Precision: 0.9383
# Recall: 0.8370
# F1 Score: 0.8848
# Average Precision (AP): 0.9595
#
# Classification Report:
#               precision    recall  f1-score   support
#
# non-detected     0.8529    0.9450    0.8966      2000
#     detected     0.9383    0.8370    0.8848      2000
#
#     accuracy                         0.8910      4000
#    macro avg     0.8956    0.8910    0.8907      4000
# weighted avg     0.8956    0.8910    0.8907      4000

# %%
from numba import cuda

cuda.select_device(0)
cuda.close()
